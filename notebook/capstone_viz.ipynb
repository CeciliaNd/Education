# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
#access raw data
popdemo_df = pd.read_csv("../data/popdemographicsdatanew.csv")
popdemo_df.head()
# Out:
#    year state_name county_name census_region_name  population_estimate  \
# 0  1975    Alabama     Alabama              South                  NaN
# 1  1976    Alabama     Alabama              South                  NaN
# 2  1977    Alabama     Alabama              South                  NaN
# 3  1978    Alabama     Alabama              South                  NaN
# 4  1979    Alabama     Alabama              South                  NaN
#
#    population_white_male_25_44  population_white_female_25_44  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#    population_wh_non_hisp_lat_male_25_44  \
# 0                                    NaN
# 1                                    NaN
# ...

# %%
#checking columns
popdemo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151616 entries, 0 to 151615
# Data columns (total 26 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   year                                       151616 non-null  object
#  1   state_name                                 151616 non-null  object
#  2   county_name                                151616 non-null  object
#  3   census_region_name                         147154 non-null  object
#  4   population_estimate                        74866 non-null   float64
#  5   population_white_male_25_44                44853 non-null   float64
#  6   population_white_female_25_44              44853 non-null   float64
#  7   population_wh_non_hisp_lat_male_25_44      44853 non-null   float64
#  8   population_wh_non_hisp_lat_female_25_44    44853 non-null   float64
# ...

# %%
# Display columns and NA's in dataframe 
popdemo_df.isna().sum()
# Out:
# year                                              0
# state_name                                        0
# county_name                                       0
# census_region_name                             4462
# population_estimate                           76750
# population_white_male_25_44                  106763
# population_white_female_25_44                106763
# population_wh_non_hisp_lat_male_25_44        106763
# population_wh_non_hisp_lat_female_25_44      106763
# population_black_afr_am_male_25_44           106763
# population_black_afr_am_female_25_44         106763
# population_am_ind_alaska_nat_male_25_44      106763
# population_am_ind_alaska_nat_femle_25_44     106763
# population_asian_male_25_44                  106763
# population_asian_female_25_44                106763
# population_nat_haw_oth_pac_isl_male_25_44    106763
# population_nat_haw_oth_pac_isl_fem_25_44     106763
# population_male_25_44                        105631
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 #access raw data
# ----> 2 popdemo_df = pd.read_csv(educationdata.csv)
#
# NameError: name 'educationdata' is not defined
